# %%
# !python -m venv myenv

# %%
# !myenv\Scripts\activate

# %%
# !pip install tensorflow==2.17.0
# Out:
# Requirement already satisfied: tensorflow==2.17.0 in c:\users\rohan\anaconda3\lib\site-packages (2.17.0)
# Requirement already satisfied: tensorflow-intel==2.17.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow==2.17.0) (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (3.3.0)
# Requirement already satisfied: packaging in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (1.65.4)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (0.31.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow==2.17.0) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\rohan\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.17.0->tensorflow==2.17.0) (0.43.0)
# Requirement already satisfied: rich in c:\users\rohan\anaconda3\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow==2.17.0) (13.7.1)
# Requirement already satisfied: namex in c:\users\rohan\anaconda3\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow==2.17.0) (0.0.8)
# Requirement already satisfied: optree in c:\users\rohan\anaconda3\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow==2.17.0) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rohan\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow==2.17.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rohan\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow==2.17.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rohan\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow==2.17.0) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rohan\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow==2.17.0) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\rohan\anaconda3\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow==2.17.0) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow==2.17.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\rohan\anaconda3\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow==2.17.0) (3.0.3)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\rohan\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow==2.17.0) (7.0.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\rohan\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow==2.17.0) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\rohan\anaconda3\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow==2.17.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\rohan\anaconda3\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow==2.17.0) (2.18.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\rohan\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow==2.17.0) (3.17.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\rohan\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow==2.17.0) (0.1.2)

# %%
import cv2
from retinaface import RetinaFace
# Load the image
image_path = 'aadhar.jpg'  # Replace with the path to your image
image = cv2.imread(image_path)
# Detect faces in the image
faces = RetinaFace.detect_faces(image)

# Check if any face is detected
if len(faces) == 0:
    print("No face detected.")
else:
    print(f"Detected {len(faces)} face(s).")
# Extract the face based on the detected bounding box
for key, face in faces.items():
    # Get bounding box coordinates
    facial_area = face['facial_area']
    x1, y1, x2, y2 = facial_area

    # Crop the face from the image
    extracted_face = image[y1:y2, x1:x2]

    # Save the extracted face
    output_path = 'extracted_face_dlb.jpg'
    cv2.imwrite(output_path, extracted_face)
    print(f"Face extracted and saved at {output_path}.")
    
    # Optional: Display the extracted face
    cv2.imshow("Extracted Face", extracted_face)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 7
#       5 image = cv2.imread(image_path)
#       6 # Detect faces in the image
# ----> 7 faces = RetinaFace.detect_faces(image)
#       9 # Check if any face is detected
#      10 if len(faces) == 0:
#
# File ~\anaconda3\lib\site-packages\retinaface\RetinaFace.py:96, in detect_faces(img_path, threshold, model, allow_upscaling)
#      93 # ---------------------------
#      95 if model is None:
# ---> 96     model = build_model()
#      98 # ---------------------------
#     100 nms_threshold = 0.4
#
# File ~\anaconda3\lib\site-packages\retinaface\RetinaFace.py:54, in build_model()
#      50 global model  # singleton design pattern
#      52 if not "model" in globals():
#      53     model = tf.function(
# ---> 54         retinaface_model.build_model(),
#      55         input_signature=(tf.TensorSpec(shape=[None, None, None, 3], dtype=np.float32),),
#      56     )
#      58 return model
#
# File ~\anaconda3\lib\site-packages\retinaface\model\retinaface_model.py:1027, in build_model()
#    1019 ssh_m3_det_conv1_bn = BatchNormalization(
#    1020     epsilon=1.9999999494757503e-05, name="ssh_m3_det_conv1_bn", trainable=False
#    1021 )(ssh_m3_det_conv1)
#    1023 ssh_m3_det_context_conv1_bn = BatchNormalization(
#    1024     epsilon=1.9999999494757503e-05, name="ssh_m3_det_context_conv1_bn", trainable=False
#    1025 )(ssh_m3_det_context_conv1)
# -> 1027 x1_shape = tf.shape(ssh_c3_up)
#    1028 x2_shape = tf.shape(ssh_c2_lateral_relu)
#    1029 offsets = [0, (x1_shape[1] - x2_shape[1]) // 2, (x1_shape[2] - x2_shape[2]) // 2, 0]
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~\anaconda3\lib\site-packages\keras\src\backend\common\keras_tensor.py:91, in KerasTensor.__tf_tensor__(self, dtype, name)
#      90 def __tf_tensor__(self, dtype=None, name=None):
# ---> 91     raise ValueError(
#      92         "A KerasTensor cannot be used as input to a TensorFlow function. "
#      93         "A KerasTensor is a symbolic placeholder for a shape and dtype, "
#      94         "used when constructing Keras Functional models "
#      95         "or Keras Functions. You can only use it as input to a Keras layer "
#      96         "or a Keras operation (from the namespaces `keras.layers` "
#      97         "and `keras.operations`). "
#      98         "You are likely doing something like:\n\n"
#      99         "```\n"
#     100         "x = Input(...)\n"
#     101         "...\n"
#     102         "tf_fn(x)  # Invalid.\n"
#     103         "```\n\n"
#     104         "What you should do instead is wrap `tf_fn` in a layer:\n\n"
#     105         "```\n"
#     106         "class MyLayer(Layer):\n"
#     107         "    def call(self, x):\n"
#     108         "        return tf_fn(x)\n\n"
#     109         "x = MyLayer()(x)\n"
#     110         "```\n"
#     111     )
#
# ValueError: A KerasTensor cannot be used as input to a TensorFlow function. A KerasTensor is a symbolic placeholder for a shape and dtype, used when constructing Keras Functional models or Keras Functions. You can only use it as input to a Keras layer or a Keras operation (from the namespaces `keras.layers` and `keras.operations`). You are likely doing something like:
#
# ```
# x = Input(...)
# ...
# tf_fn(x)  # Invalid.
# ```
#
# What you should do instead is wrap `tf_fn` in a layer:
#
# ```
# class MyLayer(Layer):
#     def call(self, x):
#         return tf_fn(x)
#
# x = MyLayer()(x)
# ```

# %%
import cv2
from retinaface import RetinaFace

# Load the image
image_path = 'aadhar.jpg'  # Replace with the path to your image
image = cv2.imread(image_path)

# Check if the image was loaded successfully
if image is None:
    print("Error: Image not found or unable to read the file.")
else:
    # Detect faces in the image
    faces = RetinaFace.detect_faces(image)

    # Check if any face is detected
    if len(faces) == 0:
        print("No face detected.")
    else:
        print(f"Detected {len(faces)} face(s).")

        # Extract the face based on the detected bounding box
        for key, face in faces.items():
            # Get bounding box coordinates
            facial_area = face['facial_area']
            x1, y1, x2, y2 = facial_area

            # Crop the face from the image
            extracted_face = image[y1:y2, x1:x2]

            # Save the extracted face
            output_path = 'extracted_face_dlb.jpg'
            cv2.imwrite(output_path, extracted_face)
            print(f"Face extracted and saved at {output_path}.")

            # Optional: Display the extracted face
            cv2.imshow("Extracted Face", extracted_face)
            cv2.waitKey(0)
            cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 13
#      10     print("Error: Image not found or unable to read the file.")
#      11 else:
#      12     # Detect faces in the image
# ---> 13     faces = RetinaFace.detect_faces(image)
#      15     # Check if any face is detected
#      16     if len(faces) == 0:
#
# File ~\anaconda3\lib\site-packages\retinaface\RetinaFace.py:96, in detect_faces(img_path, threshold, model, allow_upscaling)
#      93 # ---------------------------
#      95 if model is None:
# ---> 96     model = build_model()
#      98 # ---------------------------
#     100 nms_threshold = 0.4
#
# File ~\anaconda3\lib\site-packages\retinaface\RetinaFace.py:54, in build_model()
#      50 global model  # singleton design pattern
#      52 if not "model" in globals():
#      53     model = tf.function(
# ---> 54         retinaface_model.build_model(),
#      55         input_signature=(tf.TensorSpec(shape=[None, None, None, 3], dtype=np.float32),),
#      56     )
#      58 return model
#
# File ~\anaconda3\lib\site-packages\retinaface\model\retinaface_model.py:1027, in build_model()
#    1019 ssh_m3_det_conv1_bn = BatchNormalization(
#    1020     epsilon=1.9999999494757503e-05, name="ssh_m3_det_conv1_bn", trainable=False
#    1021 )(ssh_m3_det_conv1)
#    1023 ssh_m3_det_context_conv1_bn = BatchNormalization(
#    1024     epsilon=1.9999999494757503e-05, name="ssh_m3_det_context_conv1_bn", trainable=False
#    1025 )(ssh_m3_det_context_conv1)
# -> 1027 x1_shape = tf.shape(ssh_c3_up)
#    1028 x2_shape = tf.shape(ssh_c2_lateral_relu)
#    1029 offsets = [0, (x1_shape[1] - x2_shape[1]) // 2, (x1_shape[2] - x2_shape[2]) // 2, 0]
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~\anaconda3\lib\site-packages\keras\src\backend\common\keras_tensor.py:91, in KerasTensor.__tf_tensor__(self, dtype, name)
#      90 def __tf_tensor__(self, dtype=None, name=None):
# ---> 91     raise ValueError(
#      92         "A KerasTensor cannot be used as input to a TensorFlow function. "
#      93         "A KerasTensor is a symbolic placeholder for a shape and dtype, "
#      94         "used when constructing Keras Functional models "
#      95         "or Keras Functions. You can only use it as input to a Keras layer "
#      96         "or a Keras operation (from the namespaces `keras.layers` "
#      97         "and `keras.operations`). "
#      98         "You are likely doing something like:\n\n"
#      99         "```\n"
#     100         "x = Input(...)\n"
#     101         "...\n"
#     102         "tf_fn(x)  # Invalid.\n"
#     103         "```\n\n"
#     104         "What you should do instead is wrap `tf_fn` in a layer:\n\n"
#     105         "```\n"
#     106         "class MyLayer(Layer):\n"
#     107         "    def call(self, x):\n"
#     108         "        return tf_fn(x)\n\n"
#     109         "x = MyLayer()(x)\n"
#     110         "```\n"
#     111     )
#
# ValueError: A KerasTensor cannot be used as input to a TensorFlow function. A KerasTensor is a symbolic placeholder for a shape and dtype, used when constructing Keras Functional models or Keras Functions. You can only use it as input to a Keras layer or a Keras operation (from the namespaces `keras.layers` and `keras.operations`). You are likely doing something like:
#
# ```
# x = Input(...)
# ...
# tf_fn(x)  # Invalid.
# ```
#
# What you should do instead is wrap `tf_fn` in a layer:
#
# ```
# class MyLayer(Layer):
#     def call(self, x):
#         return tf_fn(x)
#
# x = MyLayer()(x)
# ```

# %%
# !pip install tensorflow==2.10.0 keras==2.10.0 --user
# Out:
# Collecting tensorflow==2.10.0
#   Using cached tensorflow-2.10.0-cp39-cp39-win_amd64.whl.metadata (3.1 kB)
# Requirement already satisfied: keras==2.10.0 in c:\users\rohan\anaconda3\lib\site-packages (2.10.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow==2.10.0) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow==2.10.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow==2.10.0) (24.3.25)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow==2.10.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow==2.10.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow==2.10.0) (3.11.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow==2.10.0) (1.1.2)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow==2.10.0) (18.1.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow==2.10.0) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow==2.10.0) (3.3.0)
# Requirement already satisfied: packaging in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow==2.10.0) (24.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow==2.10.0) (3.19.6)
# Requirement already satisfied: setuptools in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow==2.10.0) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow==2.10.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow==2.10.0) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow==2.10.0) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow==2.10.0) (1.16.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow==2.10.0) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow==2.10.0) (1.65.4)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow==2.10.0) (2.10.1)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow==2.10.0) (2.10.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\rohan\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow==2.10.0) (0.43.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\rohan\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.35.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\rohan\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\rohan\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\rohan\anaconda3\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\rohan\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\rohan\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\rohan\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\rohan\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\rohan\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (7.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rohan\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rohan\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rohan\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rohan\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2024.7.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\rohan\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.1.3)
# Requirement already satisfied: zipp>=0.5 in c:\users\rohan\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.17.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\rohan\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\rohan\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.2.2)
# Using cached tensorflow-2.10.0-cp39-cp39-win_amd64.whl (455.9 MB)
# Installing collected packages: tensorflow
# Successfully installed tensorflow-2.10.0
#   WARNING: The scripts estimator_ckpt_converter.exe, import_pb_to_tensorboard.exe, saved_model_cli.exe, tensorboard.exe, tf_upgrade_v2.exe, tflite_convert.exe, toco.exe and toco_from_protos.exe are installed in 'C:\Users\rohan\AppData\Roaming\Python\Python39\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tf-keras 2.17.0 requires tensorflow<2.18,>=2.17, but you have tensorflow 2.10.0 which is incompatible.

# %%
# !pip install mtcnn
# Out:
# Requirement already satisfied: mtcnn in c:\users\rohan\anaconda3\lib\site-packages (0.1.1)
# Requirement already satisfied: keras>=2.0.0 in c:\users\rohan\anaconda3\lib\site-packages (from mtcnn) (3.5.0)
# Requirement already satisfied: opencv-python>=4.1.0 in c:\users\rohan\anaconda3\lib\site-packages (from mtcnn) (4.10.0.84)
# Requirement already satisfied: absl-py in c:\users\rohan\anaconda3\lib\site-packages (from keras>=2.0.0->mtcnn) (2.1.0)
# Requirement already satisfied: numpy in c:\users\rohan\anaconda3\lib\site-packages (from keras>=2.0.0->mtcnn) (1.26.4)
# Requirement already satisfied: rich in c:\users\rohan\anaconda3\lib\site-packages (from keras>=2.0.0->mtcnn) (13.7.1)
# Requirement already satisfied: namex in c:\users\rohan\anaconda3\lib\site-packages (from keras>=2.0.0->mtcnn) (0.0.8)
# Requirement already satisfied: h5py in c:\users\rohan\anaconda3\lib\site-packages (from keras>=2.0.0->mtcnn) (3.11.0)
# Requirement already satisfied: optree in c:\users\rohan\anaconda3\lib\site-packages (from keras>=2.0.0->mtcnn) (0.12.1)
# Requirement already satisfied: ml-dtypes in c:\users\rohan\anaconda3\lib\site-packages (from keras>=2.0.0->mtcnn) (0.4.0)
# Requirement already satisfied: packaging in c:\users\rohan\anaconda3\lib\site-packages (from keras>=2.0.0->mtcnn) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\rohan\anaconda3\lib\site-packages (from optree->keras>=2.0.0->mtcnn) (4.11.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\rohan\anaconda3\lib\site-packages (from rich->keras>=2.0.0->mtcnn) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\rohan\anaconda3\lib\site-packages (from rich->keras>=2.0.0->mtcnn) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\rohan\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=2.0.0->mtcnn) (0.1.2)

# %%
import cv2
from mtcnn import MTCNN

def detect_face(image):
    """
    Detect faces in an image using MTCNN.
    """
    detector = MTCNN()
    faces = detector.detect_faces(image)
    return faces

def extract_face(image, face):
    """
    Extract the face from the image based on the bounding box provided by MTCNN.
    """
    x, y, width, height = face['box']  # Extract the bounding box
    # Ensure the bounding box is within image dimensions
    x = max(0, x)
    y = max(0, y)
    width = min(width, image.shape[1] - x)
    height = min(height, image.shape[0] - y)
    extracted_face = image[y:y + height, x:x + width]
    return extracted_face

def rotate_image(image, angle):
    """
    Rotate the image by the specified angle.
    """
    (h, w) = image.shape[:2]
    center = (w // 2, h // 2)

    # Perform the rotation
    matrix = cv2.getRotationMatrix2D(center, angle, 1.0)
    rotated = cv2.warpAffine(image, matrix, (w, h))
    return rotated

# Main workflow
image_path = 'parag.jpg'  # Replace with your preprocessed image path
image = cv2.imread(image_path)

# Convert the image to RGB
rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# Attempt to detect faces
faces = detect_face(rgb_image)

# Define the angles to try if no faces are detected
rotation_angles = [0,90, 180, 270]

# Rotate the image if no faces are detected
for angle in rotation_angles:
    if faces:  # Break the loop if faces are found
        break
    print(f"No face detected. Rotating the image by {angle} degrees.")
    rgb_image = rotate_image(rgb_image, angle)
    faces = detect_face(rgb_image)

# Process the detected face
if faces:
    # Extract the first detected face
    extracted_face = extract_face(rgb_image, faces[0])

    # Save the extracted face
    output_path = 'extracted_face_parag.jpg'
    cv2.imwrite(output_path, cv2.cvtColor(extracted_face, cv2.COLOR_RGB2BGR))  # Save as BGR for OpenCV
    print(f"Face extracted and saved at {output_path}.")

    # Optionally display the extracted face
    cv2.imshow('Extracted Face', extracted_face)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
else:
    print("No faces detected in the image after all rotations.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 2
#       1 import cv2
# ----> 2 from mtcnn import MTCNN
#       4 def detect_face(image):
#       5     """
#       6     Detect faces in an image using MTCNN.
#       7     """
#
# File ~\anaconda3\lib\site-packages\mtcnn\__init__.py:26
#       1 #!/usr/bin/python3
#       2 # -*- coding: utf-8 -*-
#       3
#    (...)
#      23 # OUT OF OR IN CONNECTION WITH THE SOFTWARE OR THE USE OR OTHER DEALINGS IN THE
#      24 # SOFTWARE.
# ---> 26 from mtcnn.mtcnn import MTCNN
#      29 __author__ = "Iván de Paz Centeno"
#      30 __version__= "0.1.0"
#
# File ~\anaconda3\lib\site-packages\mtcnn\mtcnn.py:37
#      34 import pkg_resources
#      36 from mtcnn.exceptions import InvalidImage
# ---> 37 from mtcnn.network.factory import NetworkFactory
#      39 __author__ = "Iván de Paz Centeno"
#      42 class StageStatus(object):
#
# File ~\anaconda3\lib\site-packages\mtcnn\network\factory.py:26
#       1 #!/usr/bin/python3
#       2 # -*- coding: utf-8 -*-
#       3
#    (...)
#      23 # OUT OF OR IN CONNECTION WITH THE SOFTWARE OR THE USE OR OTHER DEALINGS IN THE
#      24 # SOFTWARE.
# ---> 26 from tensorflow.keras.layers import Input, Dense, Conv2D, MaxPooling2D, PReLU, Flatten, Softmax
#      27 from tensorflow.keras.models import Model
#      29 import numpy as np
#
# File ~\anaconda3\lib\site-packages\tensorflow\__init__.py:45
#      42 from tensorflow.python import tf2 as _tf2
#      43 _tf2.enable()
# ---> 45 from ._api.v2 import __internal__
#      46 from ._api.v2 import __operators__
#      47 from ._api.v2 import audio
#
# File ~\anaconda3\lib\site-packages\tensorflow\_api\v2\__internal__\__init__.py:11
#       9 from . import decorator
#      10 from . import dispatch
# ---> 11 from . import distribute
#      12 from . import eager_context
#      13 from . import feature_column
#
# File ~\anaconda3\lib\site-packages\tensorflow\_api\v2\__internal__\distribute\__init__.py:11
#       9 from . import interim
#      10 from . import multi_process_runner
# ---> 11 from tensorflow.python.distribute.distribution_strategy_context import variable_sync_on_read_context
#      12 from tensorflow.python.distribute.merge_call_interim import strategy_supports_no_merge_call
#      13 from tensorflow.python.distribute.sharded_variable import ShardedVariable
#
# ModuleNotFoundError: No module named 'tensorflow.python.distribute.distribution_strategy_context'

# %%
def extract_face_dlib(image_path):
    # Load the image
    image = cv2.imread(image_path)
    
    # Convert the image to RGB (dlib uses RGB instead of BGR)
    rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    
    # Initialize dlib's face detector
    detector = dlib.get_frontal_face_detector()
    
    # Detect faces in the image
    detected_faces = detector(rgb_image, 1)
    
    # Assuming there is only one face, extract it
    if len(detected_faces) == 1:
        face = detected_faces[0]
        # Extract the face using the bounding box coordinates
        x, y, w, h = face.left(), face.top(), face.width(), face.height()
        extracted_face = image[y:y + h, x:x + w]
        return extracted_face
    else:
        print("No face detected or multiple faces detected.")
        return None

# Main workflow
image_path = 'aadhar.jpg'  # Replace with your document image path

# Extract the face from the document
extracted_face = extract_face_dlib(image_path)

# Check if extraction was successful
if extracted_face is not None:
    # Save the extracted face
    output_path = 'extracted_face_dlib.jpg'
    cv2.imwrite(output_path, extracted_face)

    # Optionally display the extracted face
    cv2.imshow('Extracted Face', extracted_face)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 29
#      26 image_path = 'aadhar.jpg'  # Replace with your document image path
#      28 # Extract the face from the document
# ---> 29 extracted_face = extract_face_dlib(image_path)
#      31 # Check if extraction was successful
#      32 if extracted_face is not None:
#      33     # Save the extracted face
#
# Cell In[4], line 9, in extract_face_dlib(image_path)
#       6 rgb_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#       8 # Initialize dlib's face detector
# ----> 9 detector = dlib.get_frontal_face_detector()
#      11 # Detect faces in the image
#      12 detected_faces = detector(rgb_image, 1)
#
# NameError: name 'dlib' is not defined

# %%
# !pip install tf-keras
# Out:
# Requirement already satisfied: tf-keras in c:\users\rohan\anaconda3\lib\site-packages (2.17.0)
# Requirement already satisfied: tensorflow<2.18,>=2.17 in c:\users\rohan\anaconda3\lib\site-packages (from tf-keras) (2.17.0)
# Requirement already satisfied: tensorflow-intel==2.17.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow<2.18,>=2.17->tf-keras) (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras) (3.3.0)
# Requirement already satisfied: packaging in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras) (4.25.5)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras) (1.65.4)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras) (0.31.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras) (1.26.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\rohan\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras) (0.43.0)
# Requirement already satisfied: rich in c:\users\rohan\anaconda3\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras) (13.7.1)
# Requirement already satisfied: namex in c:\users\rohan\anaconda3\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras) (0.0.8)
# Requirement already satisfied: optree in c:\users\rohan\anaconda3\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rohan\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rohan\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rohan\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rohan\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras) (2024.7.4)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\rohan\anaconda3\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\rohan\anaconda3\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras) (3.0.3)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\rohan\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras) (7.0.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\rohan\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\rohan\anaconda3\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\rohan\anaconda3\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras) (2.18.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\rohan\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras) (3.17.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\rohan\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow<2.18,>=2.17->tf-keras) (0.1.2)

# %%
# !pip install opencv_python retina-face
# Out:
# Requirement already satisfied: opencv_python in c:\users\rohan\anaconda3\lib\site-packages (4.10.0.84)
# Requirement already satisfied: retina-face in c:\users\rohan\anaconda3\lib\site-packages (0.0.17)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\rohan\anaconda3\lib\site-packages (from opencv_python) (1.26.4)
# Requirement already satisfied: gdown>=3.10.1 in c:\users\rohan\anaconda3\lib\site-packages (from retina-face) (5.2.0)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\rohan\anaconda3\lib\site-packages (from retina-face) (10.4.0)
# Requirement already satisfied: tensorflow>=1.9.0 in c:\users\rohan\anaconda3\lib\site-packages (from retina-face) (2.17.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\rohan\anaconda3\lib\site-packages (from gdown>=3.10.1->retina-face) (4.12.3)
# Requirement already satisfied: filelock in c:\users\rohan\anaconda3\lib\site-packages (from gdown>=3.10.1->retina-face) (3.13.1)
# Requirement already satisfied: requests[socks] in c:\users\rohan\anaconda3\lib\site-packages (from gdown>=3.10.1->retina-face) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\rohan\anaconda3\lib\site-packages (from gdown>=3.10.1->retina-face) (4.66.4)
# Requirement already satisfied: tensorflow-intel==2.17.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow>=1.9.0->retina-face) (2.17.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=1.9.0->retina-face) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=1.9.0->retina-face) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=1.9.0->retina-face) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=1.9.0->retina-face) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=1.9.0->retina-face) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=1.9.0->retina-face) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=1.9.0->retina-face) (18.1.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.3.1 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=1.9.0->retina-face) (0.4.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=1.9.0->retina-face) (3.3.0)
# Requirement already satisfied: packaging in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=1.9.0->retina-face) (24.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=1.9.0->retina-face) (4.25.5)
# Requirement already satisfied: setuptools in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=1.9.0->retina-face) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=1.9.0->retina-face) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=1.9.0->retina-face) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=1.9.0->retina-face) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=1.9.0->retina-face) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=1.9.0->retina-face) (1.65.4)
# Requirement already satisfied: tensorboard<2.18,>=2.17 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=1.9.0->retina-face) (2.17.1)
# Requirement already satisfied: keras>=3.2.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=1.9.0->retina-face) (3.5.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\rohan\anaconda3\lib\site-packages (from tensorflow-intel==2.17.0->tensorflow>=1.9.0->retina-face) (0.31.0)
# Requirement already satisfied: soupsieve>1.2 in c:\users\rohan\anaconda3\lib\site-packages (from beautifulsoup4->gdown>=3.10.1->retina-face) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rohan\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->retina-face) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rohan\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->retina-face) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rohan\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->retina-face) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rohan\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->retina-face) (2024.7.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\rohan\anaconda3\lib\site-packages (from requests[socks]->gdown>=3.10.1->retina-face) (1.7.1)
# Requirement already satisfied: colorama in c:\users\rohan\anaconda3\lib\site-packages (from tqdm->gdown>=3.10.1->retina-face) (0.4.6)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\rohan\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.17.0->tensorflow>=1.9.0->retina-face) (0.43.0)
# Requirement already satisfied: rich in c:\users\rohan\anaconda3\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow>=1.9.0->retina-face) (13.7.1)
# Requirement already satisfied: namex in c:\users\rohan\anaconda3\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow>=1.9.0->retina-face) (0.0.8)
# Requirement already satisfied: optree in c:\users\rohan\anaconda3\lib\site-packages (from keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow>=1.9.0->retina-face) (0.12.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\rohan\anaconda3\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow>=1.9.0->retina-face) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\rohan\anaconda3\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow>=1.9.0->retina-face) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\rohan\anaconda3\lib\site-packages (from tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow>=1.9.0->retina-face) (3.0.3)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\rohan\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow>=1.9.0->retina-face) (7.0.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\rohan\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow>=1.9.0->retina-face) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\rohan\anaconda3\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow>=1.9.0->retina-face) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\rohan\anaconda3\lib\site-packages (from rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow>=1.9.0->retina-face) (2.18.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\rohan\anaconda3\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.18,>=2.17->tensorflow-intel==2.17.0->tensorflow>=1.9.0->retina-face) (3.17.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\rohan\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->tensorflow-intel==2.17.0->tensorflow>=1.9.0->retina-face) (0.1.2)

# %%
import cv2
from retinaface import RetinaFace
# Load the image
image_path = 'aadhar.jpg'  # Replace with the path to your image
image = cv2.imread(image_path)
# Detect faces in the image
faces = RetinaFace.detect_faces(image)

# Check if any face is detected
if len(faces) == 0:
    print("No face detected.")
else:
    print(f"Detected {len(faces)} face(s).")
# Extract the face based on the detected bounding box
for key, face in faces.items():
    # Get bounding box coordinates
    facial_area = face['facial_area']
    x1, y1, x2, y2 = facial_area

    # Crop the face from the image
    extracted_face = image[y1:y2, x1:x2]

    # Save the extracted face
    output_path = 'extracted_face_dlb.jpg'
    cv2.imwrite(output_path, extracted_face)
    print(f"Face extracted and saved at {output_path}.")
    
    # Optional: Display the extracted face
    cv2.imshow("Extracted Face", extracted_face)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 7
#       5 image = cv2.imread(image_path)
#       6 # Detect faces in the image
# ----> 7 faces = RetinaFace.detect_faces(image)
#       9 # Check if any face is detected
#      10 if len(faces) == 0:
#
# File ~\anaconda3\lib\site-packages\retinaface\RetinaFace.py:96, in detect_faces(img_path, threshold, model, allow_upscaling)
#      93 # ---------------------------
#      95 if model is None:
# ---> 96     model = build_model()
#      98 # ---------------------------
#     100 nms_threshold = 0.4
#
# File ~\anaconda3\lib\site-packages\retinaface\RetinaFace.py:54, in build_model()
#      50 global model  # singleton design pattern
#      52 if not "model" in globals():
#      53     model = tf.function(
# ---> 54         retinaface_model.build_model(),
#      55         input_signature=(tf.TensorSpec(shape=[None, None, None, 3], dtype=np.float32),),
#      56     )
#      58 return model
#
# File ~\anaconda3\lib\site-packages\retinaface\model\retinaface_model.py:1027, in build_model()
#    1019 ssh_m3_det_conv1_bn = BatchNormalization(
#    1020     epsilon=1.9999999494757503e-05, name="ssh_m3_det_conv1_bn", trainable=False
#    1021 )(ssh_m3_det_conv1)
#    1023 ssh_m3_det_context_conv1_bn = BatchNormalization(
#    1024     epsilon=1.9999999494757503e-05, name="ssh_m3_det_context_conv1_bn", trainable=False
#    1025 )(ssh_m3_det_context_conv1)
# -> 1027 x1_shape = tf.shape(ssh_c3_up)
#    1028 x2_shape = tf.shape(ssh_c2_lateral_relu)
#    1029 offsets = [0, (x1_shape[1] - x2_shape[1]) // 2, (x1_shape[2] - x2_shape[2]) // 2, 0]
#
# File ~\anaconda3\lib\site-packages\tensorflow\python\util\traceback_utils.py:153, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
# --> 153   raise e.with_traceback(filtered_tb) from None
#     154 finally:
#     155   del filtered_tb
#
# File ~\anaconda3\lib\site-packages\keras\src\backend\common\keras_tensor.py:91, in KerasTensor.__tf_tensor__(self, dtype, name)
#      90 def __tf_tensor__(self, dtype=None, name=None):
# ---> 91     raise ValueError(
#      92         "A KerasTensor cannot be used as input to a TensorFlow function. "
#      93         "A KerasTensor is a symbolic placeholder for a shape and dtype, "
#      94         "used when constructing Keras Functional models "
#      95         "or Keras Functions. You can only use it as input to a Keras layer "
#      96         "or a Keras operation (from the namespaces `keras.layers` "
#      97         "and `keras.operations`). "
#      98         "You are likely doing something like:\n\n"
#      99         "```\n"
#     100         "x = Input(...)\n"
#     101         "...\n"
#     102         "tf_fn(x)  # Invalid.\n"
#     103         "```\n\n"
#     104         "What you should do instead is wrap `tf_fn` in a layer:\n\n"
#     105         "```\n"
#     106         "class MyLayer(Layer):\n"
#     107         "    def call(self, x):\n"
#     108         "        return tf_fn(x)\n\n"
#     109         "x = MyLayer()(x)\n"
#     110         "```\n"
#     111     )
#
# ValueError: A KerasTensor cannot be used as input to a TensorFlow function. A KerasTensor is a symbolic placeholder for a shape and dtype, used when constructing Keras Functional models or Keras Functions. You can only use it as input to a Keras layer or a Keras operation (from the namespaces `keras.layers` and `keras.operations`). You are likely doing something like:
#
# ```
# x = Input(...)
# ...
# tf_fn(x)  # Invalid.
# ```
#
# What you should do instead is wrap `tf_fn` in a layer:
#
# ```
# class MyLayer(Layer):
#     def call(self, x):
#         return tf_fn(x)
#
# x = MyLayer()(x)
# ```

# %%
# !pip install keras
# Out:
# Requirement already satisfied: keras in c:\users\rohan\anaconda3\lib\site-packages (3.5.0)
# Requirement already satisfied: absl-py in c:\users\rohan\anaconda3\lib\site-packages (from keras) (2.1.0)
# Requirement already satisfied: numpy in c:\users\rohan\anaconda3\lib\site-packages (from keras) (1.26.4)
# Requirement already satisfied: rich in c:\users\rohan\anaconda3\lib\site-packages (from keras) (13.7.1)
# Requirement already satisfied: namex in c:\users\rohan\anaconda3\lib\site-packages (from keras) (0.0.8)
# Requirement already satisfied: h5py in c:\users\rohan\anaconda3\lib\site-packages (from keras) (3.11.0)
# Requirement already satisfied: optree in c:\users\rohan\anaconda3\lib\site-packages (from keras) (0.12.1)
# Requirement already satisfied: ml-dtypes in c:\users\rohan\anaconda3\lib\site-packages (from keras) (0.4.0)
# Requirement already satisfied: packaging in c:\users\rohan\anaconda3\lib\site-packages (from keras) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\rohan\anaconda3\lib\site-packages (from optree->keras) (4.11.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\rohan\anaconda3\lib\site-packages (from rich->keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\rohan\anaconda3\lib\site-packages (from rich->keras) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\rohan\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)

# %%
# !pip install mtcnn
# Out:
# Requirement already satisfied: mtcnn in c:\users\rohan\anaconda3\lib\site-packages (0.1.1)
# Requirement already satisfied: keras>=2.0.0 in c:\users\rohan\anaconda3\lib\site-packages (from mtcnn) (3.5.0)
# Requirement already satisfied: opencv-python>=4.1.0 in c:\users\rohan\anaconda3\lib\site-packages (from mtcnn) (4.10.0.84)
# Requirement already satisfied: absl-py in c:\users\rohan\anaconda3\lib\site-packages (from keras>=2.0.0->mtcnn) (2.1.0)
# Requirement already satisfied: numpy in c:\users\rohan\anaconda3\lib\site-packages (from keras>=2.0.0->mtcnn) (1.26.4)
# Requirement already satisfied: rich in c:\users\rohan\anaconda3\lib\site-packages (from keras>=2.0.0->mtcnn) (13.7.1)
# Requirement already satisfied: namex in c:\users\rohan\anaconda3\lib\site-packages (from keras>=2.0.0->mtcnn) (0.0.8)
# Requirement already satisfied: h5py in c:\users\rohan\anaconda3\lib\site-packages (from keras>=2.0.0->mtcnn) (3.11.0)
# Requirement already satisfied: optree in c:\users\rohan\anaconda3\lib\site-packages (from keras>=2.0.0->mtcnn) (0.12.1)
# Requirement already satisfied: ml-dtypes in c:\users\rohan\anaconda3\lib\site-packages (from keras>=2.0.0->mtcnn) (0.4.0)
# Requirement already satisfied: packaging in c:\users\rohan\anaconda3\lib\site-packages (from keras>=2.0.0->mtcnn) (24.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in c:\users\rohan\anaconda3\lib\site-packages (from optree->keras>=2.0.0->mtcnn) (4.11.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\rohan\anaconda3\lib\site-packages (from rich->keras>=2.0.0->mtcnn) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\rohan\anaconda3\lib\site-packages (from rich->keras>=2.0.0->mtcnn) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\rohan\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=2.0.0->mtcnn) (0.1.2)

# %%
import cv2
import numpy as np

def preprocess_for_face_detection(image_path):
    # Read the image
    image = cv2.imread(image_path, cv2.IMREAD_COLOR)

    # Convert to grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # Enhance contrast using CLAHE
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    gray = clahe.apply(gray)

    # Apply Gaussian blur to reduce noise
    gray = cv2.GaussianBlur(gray, (5, 5), 0)

    # Darken the grayscale image
    dark_gray = cv2.addWeighted(gray, 0.5, np.zeros(gray.shape, gray.dtype), 0, 0)  # Reduces brightness

    # Use Canny edge detection
    edges = cv2.Canny(dark_gray, 50, 150)

    # Optional: Resize image to standard size
    processed_image = cv2.resize(dark_gray, (600, 400))

    return processed_image

# Example usage
image_path = 'parag.jpg'  # Replace with your image path
processed_image = preprocess_for_face_detection(image_path)

# Optionally save or display the processed image
cv2.imwrite('processed_image.jpg', processed_image)
cv2.imshow('Processed Image', processed_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
